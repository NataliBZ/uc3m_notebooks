# %% [markdown]
# <center><font size = "8">Analysis of electro-physiological traces<center>

# %% [markdown]
# <font size=4><font color=blue> In this notebook you will learn:
# <ul style="color: blue; font-size: 18px;">
#     <li> to ifferenciate two different cell types depending on their firing pattern with subthres-hold and supra-threshold stimulations</li>
#     <li> to analyse real single cell traces with different stimulations</li>
#     <li> to analyse synaptic traces and differenciate between action potentials and post-synaptic potentials</li>
# </ul>

# %% [markdown]
# <p style="color: red; font-size: 16px;"><b>IMPORTANT:</b> this notebook is using <b>Python</b> code to help you load, visualize and analyze the morphologies.</p>
# <ul style="color: red; font-size: 16px;">
#   <li><b>YOU DON'T NEED TO KNOW HOW TO CODE!</b> (you will learn to code in future courses)</li>
#   <li>YOU WOULD ONLY RUN THE CELLS. To run the cells: </li>
#     <ul style="color: red; font-size: 16px;">
#         <li>Click once on one of the cells, you will notice that it is sellected because it is highlighted in blue.</li>
#         <li>Press "Command+enter" or click on the Run (triangle) button at the top of the page.</li>
#         <li>Consider that cells <b>must be run by order</b> </li>
#     </ul>
# </ul>

# %%
# This will compile the mechanisms inside the MOD files (and create a new folder arm64).
! nrnivmodl
# Out:
# /usr/bin/xcrun
# /Users/natalibarroszulaica/Desktop/OBI/UC3M/UC3M_notebooks_tutorials_LOCAL/uc3m_notebooks/Cellular/04_Analysis_of_traces
#  "./SKv3_1.mod"aTs2_t.mod" "./SK_E2.mod"
#
#  -> Compiling mod_func.cpp
#  => LINKING shared library ./libnrnmech.dylib
# Successfully created arm64/special

# %% [markdown]
# ## 1. Studying single cell passive and active properties: sub-threshold and supra-threshold stimulations

# %%
# Load usefull packages
# %matplotlib inline

from neuron import h
import hoc
import matplotlib.pyplot as plt
import numpy as np
import math as m
import neurom as nm
from neurom import view
import pandas as pd
import h5py
import csv
import glob

import efel
from json2html import *
import IPython

import instantiate_neuron as IN
import stimuli
import Relevant_functions as rf
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.

# %% [markdown]
# ## Sub-threshold stimulation
#
# <ul style="font-size: 18px;">
#     <li>A current pulse that does not reach the threshold needed to trigger an action potential.</li>
#     <li>The cell responds only with a graded change in membrane potential (a depolarization or hyperpolarization), but no spike is fired.</li>
#     <li>Useful to study passive properties of the membrane (e.g., input resistance, capacitance, time constant).</li>
# </ul>

# %%
stim_ampl_1 = np.arange(- 0.05, 0.01, 0.008)

filename1 = 'data/Cell_01.asc'
filename2 = 'data/Cell_02.asc'

fig, axs = plt.subplots(2, 2, figsize=(12, 6), sharex=True)

# Left column: neuron 1
stimuli.SquarePulses_stim(stim_ampl_1, filename1, 'Sub_threshold_cell1.csv', axs=axs[:,0])

# Right column: neuron 2
stimuli.SquarePulses_stim(stim_ampl_1, filename2, 'Sub_threshold_cell2.csv', axs=axs[:,1])

fig.suptitle('Subthreshold stimulation')
plt.tight_layout()
plt.show()
# Out:
# 5771 lines read
#
# data/Cell_01.asc problems
#
#
# Main branch starting at line 31 is outside the soma bounding boxes
#   Making a logical connection to center of nearest soma
#
# 15199 lines read

# %% [markdown]
# __Notice:__

# %% [markdown]
# # Supra-threshold stimulation
#
# <ul style="font-size: 18px;">
#     <li>A current pulse that exceeds the threshold for firing.</li>
#     <li>The depolarization activates voltage-gated channels, and the cell generates an action potential (all-or-none spike).</li>
#     <li>Useful to study active properties of the neuron (e.g., action potential shape, firing patterns, excitability).</li>
# </ul>

# %%
stim_ampl_2 = np.arange(0.01, 5.0, 0.5)

fig, axs = plt.subplots(2, 2, figsize=(12, 6), sharex=True)

# Left column: neuron 1
stimuli.SquarePulses_stim(stim_ampl_2, filename1, 'Sub_threshold_cell1.csv', axs=axs[:,0])

# Right column: neuron 2
stimuli.SquarePulses_stim(stim_ampl_2, filename2, 'Sub_threshold_cell2.csv', axs=axs[:,1])

fig.suptitle('Suprathreshold stimulation')
plt.tight_layout()
plt.show()
# Out:
# 5771 lines read
#
# data/Cell_01.asc problems
#
#
# Main branch starting at line 31 is outside the soma bounding boxes
#   Making a logical connection to center of nearest soma
#
# 15199 lines read

# %% [markdown]
# __Notice:__

# %% [markdown]
# ## 2. Analysing real single cell recordings from patch-clamp experiments

# %% [markdown]
# <ul style="font-size: 18px;">
# These type of experiments, similarly to the ones shown above, are done by stimulating and recording simultaneously on the cell soma.
# </ul>
#
# ### Traces description
#
# <ul style="font-size: 18px;">
#     <li>The files inside the "data" folder, are named with: stimuli type (e.g. "APWaveform", "FirePattern", "IV").</li>
#     <li>Sweep (repetition) number: (e.g. "APWaveform_46-51"), of increasing/decreasing amplitudes.</li>
#     <li>Note that we have pairs of recordings with the same trace number (e.g. "exp_APWaveform_ch7_51.dat" and "exp_APWaveform_ch6_51.dat"). One of them contains the current stimulus (in this case "*ch7*") and the other the voltage response (in this case "*ch6*").</li>
# </ul>
#
# ### For the analyses:
#
# <p style="font-size: 18px;">
# We will use a library called <a href="https://efel.readthedocs.io/en/latest/eFeatures.html#burst-isi-indices" target="_blank">eFEL</a>. Click on the link if you rae curious about what parameters you can extract from this type of traces.
# </p>

# %%
# Open and plot files

# Save filenames in different lists
APWave_list = []
for filename in glob.glob('data/exp_APWaveform_ch6_*.dat'):
    APWave_list.append(filename)

APWave_I_list = []
for filename in glob.glob('data/exp_APWaveform_ch7_*.dat'):
    APWave_I_list.append(filename)

FirePattern_list = []
for filename in glob.glob('data/exp_FirePattern_ch6_*.dat'):
    FirePattern_list.append(filename)

FirePattern_I_list = []
for filename in glob.glob('data/exp_FirePattern_ch7_*.dat'):
    FirePattern_I_list.append(filename)

IV_list = []
for filename in glob.glob('data/exp_IV_ch6_*.dat'):
    IV_list.append(filename)

IV_I_list = []
for filename in glob.glob('data/exp_IV_ch7_*.dat'):
    IV_I_list.append(filename)
    
# Plot data
plt.figure(figsize=(15,3))
plt.title('APWaveform')
for fv in APWave_list:
    t, v = rf.get_data(fv)
    plt.plot(t,v)

plt.figure(figsize=(15,3))
plt.title('FirePattern')
for fv in FirePattern_list:
    t, v = rf.get_data(fv)
    plt.plot(t,v)

plt.figure(figsize=(15,3))
plt.title('IV')
for fv in IV_list:
    t, v = rf.get_data(fv)
    plt.plot(t,v)
    
plt.figure(figsize=(15,3))
plt.title('IV stim')
for fv in IV_I_list:
    t, v = rf.get_data(fv)
    plt.plot(t,v)

# %% [markdown]
# __Notice:__

# %%
#using eFEL

for fv in FirePattern_list:
    t, v = rf.get_data(fv)
    #t, i = get_data(file_c1)

    stim_start = 378.9 # in ms
    stim_end = 3681.0
    trace = {'T': t, 'V': v, 'stim_start': [stim_start], 'stim_end': [stim_end]}
   
    #Find the mean firing freq., after hyperpol depth and spikecount 
    feature_values = efel.getFeatureValues([trace], ['mean_frequency', 'AHP_depth', 'Spikecount'])[0]
    print(feature_values)
    feature_values = {feature_name: list(values) for feature_name, values in feature_values.items()}
    IPython.display.HTML(json2html.convert(json=feature_values))

 
for fv in IV_list:
    t, v = rf.get_data(fv)

    stim_start = 378.9 # in ms
    stim_end = 3681.0
    trace = {'T': t, 'V': v, 'stim_start': [stim_start], 'stim_end': [stim_end]}

    feature_values = efel.getFeatureValues([trace], ['voltage_base'])[0]
    print(feature_values)
    feature_values = {feature_name: list(values) for feature_name, values in feature_values.items()}
    IPython.display.HTML(json2html.convert(json=feature_values))
# Out:
# {'mean_frequency': array([8.82862999]), 'AHP_depth': array([-10.81383583,  -9.29508659,  -8.89508507,  -9.11383888,
#         -8.85758659,  -8.88883659,  -8.95758888,  -8.95133659,
#         -8.71383354,  -8.91383812,  -8.17633507,  -8.83258507,
#         -8.60758659,  -8.67633507,  -8.92008659,  -8.32633659,
#         -8.77633735,  -8.82008812,  -8.77633735,  -9.03258583,
#         -9.1950843 ,  -9.55758735,  -9.33883735,  -9.51383659,
#         -9.31383583,  -9.31383583,  -9.6638343 ,  -9.74508735,
#         -9.45133659,  -9.58883354]), 'Spikecount': array([30])}
# {'mean_frequency': array([16.36314051]), 'AHP_depth': array([-5.55560448, -4.5556083 , -4.29935601, -3.69935753, -3.56810524,
#        -4.01185753, -3.69310524, -3.8368583 , -3.8681083 , -2.98060753,
#        -3.16185524, -3.24310448, -3.26185753, -4.11185601, -3.5868583 ,
#        -3.01185753, -2.91185524, -3.72435524, -2.9618583 , -3.51185372,
#        -4.18685677, -3.8368583 , -3.70560601, -3.7118583 , -4.03060677,
#        -4.34935524, -3.46810677, -3.40560677, -3.81185677, -4.00560524,
#        -3.78060677, -4.7431083 , -4.1493583 , -4.22435906, -3.8368583 ,
#        -3.96810677, -4.28685524, -4.06810906, -4.23685601, -4.1806083 ,
#        -4.61185601, -4.11185601, -4.83060982, -4.3993583 , -4.40560677,
#        -4.28060677, -4.49935677, -5.13685753, -4.64310601, -4.22435906,
#        -5.37435677, -4.81185677, -4.81185677, -4.8056083 , -4.76810601,
#        -4.45560601, -5.09935906]), 'Spikecount': array([57])}
# {'voltage_base': array([-63.76276372])}
# {'voltage_base': array([-65.30928444])}
# {'voltage_base': array([-84.3593501])}
# {'voltage_base': array([-78.81624321])}
# {'voltage_base': array([-77.2736477])}
# {'voltage_base': array([-73.74968683])}
# {'voltage_base': array([-67.23240452])}
# {'voltage_base': array([-69.44378284])}
# {'voltage_base': array([-59.19150736])}
# {'voltage_base': array([-62.10207775])}
# {'voltage_base': array([-59.87678101])}
# /var/folders/jl/cqjntb9j42783g5l8cnlcv0m0000gn/T/ipykernel_12633/3659993733.py:12: DeprecationWarning: Use get_feature_values instead
#   feature_values = efel.getFeatureValues([trace], ['mean_frequency', 'AHP_depth', 'Spikecount'])[0]
# /var/folders/jl/cqjntb9j42783g5l8cnlcv0m0000gn/T/ipykernel_12633/3659993733.py:25: DeprecationWarning: Use get_feature_values instead
#   feature_values = efel.getFeatureValues([trace], ['voltage_base'])[0]

# %% [markdown]
# ## 3. Analysing post-synaptic potentials
#
# In this type of experiments what we want to see is how one neuron respond to the activity of the neuron that is connected to it.
#
# Then what we see here is the stimulation in the pre-synaptic neuron and the response of the post-synaptic neuron.
#
# ### Difference between and Action Potential and a Post-synaptic Potential
#
# Action Potential (AP)
# - What it is: A rapid, all-or-none electrical signal that travels along the axon of a neuron.
# - Where it happens: Typically starts at the axon hillock and propagates along the axon.
# - How it’s generated: Caused by the opening of voltage-gated sodium (Na⁺) and potassium (K⁺) channels. Once the threshold is reached, the full spike always occurs (all-or-none).
# - Amplitude: Large (~100 mV, from –70 mV up to +30 mV).
# - Function: Used to transmit information over long distances in the nervous system.
#
# Postsynaptic Potential (PSP)
# - What it is: A small, graded change in membrane potential in the postsynaptic neuron after neurotransmitter binding.
# - Where it happens: On the dendrites or soma of the postsynaptic neuron.
# - How it’s generated: Caused by the opening of ligand-gated ion channels (e.g., glutamate receptors, GABA receptors) when neurotransmitters bind.
# - Amplitude: Small (a few mV, usually 0.2–20 mV), and proportional to the amount of neurotransmitter released.
# - Function: They integrate (summation of many PSPs) and determine whether the postsynaptic neuron reaches threshold to fire an action potential.
# - Excitatory PSP (EPSP): depolarizes, makes firing more likely.
# - Inhibitory PSP (IPSP): hyperpolarizes, makes firing less likely.

# %%
# Open and print keys to check how many sweeps (repetitions) of the experiment there are in the file
data = h5py.File("connection_test.h5", "r")

# Create a data array and compute the mean trace by computing the mean of all sweeps
traces = []
for key in data.keys():
    traces.append(data.get(key))

traces = np.array(traces)

mean_trace = np.mean(traces, axis=0)

# plot the sweeps and the mean voltage trace
plt.figure()

for trace in traces:
    plt.plot(trace, "b--")

plt.plot(mean_trace, "r")
plt.ylabel('V (V)')
plt.xlabel('time (ms)')

# %%
time = np.linspace(0, 1.3, 13000)
stimulation_indices = np.array([1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 10000])

# %%
stimulation_time = time[stimulation_indices[0]]

psp_trace, psp_time = rf.extract_PSP_window(mean_trace, time, stimulation_indices[0])

psp_percent, psp_times, amplitude, tau_rise, latency = rf.extract_EPSP_features(
    psp_trace, psp_time, stimulation_time
)
plt.figure(figsize=(10, 5))
plt.plot(psp_time, psp_trace, label="first EPSP")
plt.scatter(psp_times["five"], psp_percent["five"], c="g", label="5%")
plt.scatter(psp_times["twenty"], psp_percent["twenty"], c="r", label="20%")
plt.scatter(psp_times["eighty"], psp_percent["eighty"], c="m", label="80%")
plt.xlabel("Time [s]")
plt.ylabel("Voltage [V]")

plt.legend()
plt.show()

print("Amplitude = ", np.abs(amplitude*1000.0), "mV")
print("Tau_rise = ", tau_rise, "s")
print("latency = ", latency, "s")

# %% [markdown]
# #### This protocol of STDP (short term dependent plasticity) has been used to classified synapses depending on the dynamics and this data can also be analysed
#
# <center><img src="Synapses.png" width="700"><center>

# %% [markdown]
# #### One very common analysis is to know the failure rate

# %% [markdown]
# #### Failure rate
#
# <font size='3'>The failure rate is the fraction of trials from which no PSP is generated above certain threshold. You can find a way of computing the failure rate in [Feldmeyer et al., 1999](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2269646/).

# %%
files = [
    "data/connection_c1.h5",
    "data/connection_c2.h5",
    "data/connection_c4.h5",
]

# %%
traces_collection = {}
for n, file in enumerate(files):
    traces_collection[n] = rf.load_traces(file)

time = np.arange(0, 1.3, 0.0001)
stimulation_indices = np.array([1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 10000])

# %%
taus_collection = {}
latencies_collection = {}
amplitudes_collection = {}

for key in traces_collection:
    traces = traces_collection[key]
    all_amplitudes, all_taus, all_latencies = rf.extract_all_amps_taus_latencies(
        traces[0], stimulation_indices, time
    )

    for trace in traces[1:]:
        amps, taus, latencies = rf.extract_all_amps_taus_latencies(trace, stimulation_indices, time)
        all_taus = np.vstack([all_taus, taus])
        all_latencies = np.vstack([all_latencies, latencies])
        all_amplitudes = np.vstack([all_amplitudes, amps])

    taus_collection[key] = all_taus
    latencies_collection[key] = all_latencies
    amplitudes_collection[key] = all_amplitudes

# %%
noise_collection = {}
for key in traces_collection:
    noise = []
    for psp_trace in traces:
        noise.append(rf.compute_noise(psp_trace, stimulation_indices[0]))

    noise_collection[key] = np.array(noise)

noise_std = pd.DataFrame(noise_collection).std()

# %%
fails0, total, failed_amps0, correct_amps0 = rf.calculate_failure_rate(
    amplitudes_collection[0], latencies_collection[0], noise_std.iloc[0]
)

fails1, _, failed_amps1, correct_amps1 = rf.calculate_failure_rate(
    amplitudes_collection[1], latencies_collection[1], noise_std.iloc[1]
)

fails2, _, failed_amps2, correct_amps2 = rf.calculate_failure_rate(
    amplitudes_collection[2], latencies_collection[2], noise_std.iloc[2]
)

# %%
data_name = ["c1", "c2", "c3"]
fails = [fails0, fails1, fails2]
plt.bar(data_name[0], fails[0] / total * 100)
plt.bar(data_name[1], fails[1] / total * 100)
plt.bar(data_name[2], fails[2] / total * 100)

plt.title("Failure rate of different connections")
plt.ylabel("Failure [%]");

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].hist(correct_amps0, bins=30, label="correct")
ax[0].hist(failed_amps0, label="failed")

ax[1].hist(correct_amps1, bins=30, label="correct")
ax[1].hist(failed_amps1, bins=2, label="failed")

ax[2].hist(correct_amps2, bins=30, label="correct")
ax[2].hist(failed_amps2, label="failed")

fig.suptitle("EPSPs Amplitude Failed/Correct")
ax[0].set_title("C_1")
ax[1].set_title("C_2")
ax[2].set_title("C_3")
ax[0].legend();
